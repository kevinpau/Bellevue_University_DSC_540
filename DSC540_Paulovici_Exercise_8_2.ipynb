# %% [markdown]
#  # Week 8: Exercise 8.2
#  File: DSC540_Paulovici_Exercise_8_2.py (.ipynb)<br>
#  Name: Kevin Paulovici<br>
#  Date: 2/2/2020<br>
#  Course: DSC 540 Data Preparation (2203-1)<br>
#  Assignment: Exercise 8.2

# %% [markdown]
#  ## Part 1
#  Connect to the Internet using Python Library urllib (Data Wrangling with Python? pg 298-300), follow the example in the book to connect to the same website or a different website and submit your code.

# %%
import urllib.parse as urllib
import urllib.request as urllib2
from pprint import pprint

# open and read Google page
google = urllib2.urlopen('http://google.com')
google = google.read()
pprint(google[:200])

# open a web page with query strings
url = 'http://google.com?q='
url_with_query = url + urllib.quote_plus('python web scraping')

web_search = urllib2.urlopen(url_with_query)
web_search = web_search.read()
print('\n')
pprint(web_search[:200])
# Out:
# (b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang='
#  b'"en"><head><meta content="Search the world\'s information, including webp'
#  b'ages, images, videos and more. Google has many speci')
#
#
# (b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang='
#  b'"en"><head><meta content="Search the world\'s information, including webp'
#  b'ages, images, videos and more. Google has many speci')

# %%
# requests tools example
import requests

google = requests.get('http://google.com')
pprint(google.status_code)
pprint(google.content[:200])
pprint(google.headers)
pprint(google.cookies.items())
# Out:
# 200
# (b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang='
#  b'"en"><head><meta content="Search the world\'s information, including webp'
#  b'ages, images, videos and more. Google has many speci')
# {'Date': 'Mon, 03 Feb 2020 04:47:00 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'Content-Length': '5563', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2020-02-03-04; expires=Wed, 04-Mar-2020 04:47:00 GMT; path=/; domain=.google.com; Secure, NID=197=NOJtNZ0V6L8qrZp3OlIpJXIfSH_IDZ8CZVOfvGKJHBMWg_N20Tyv_zFGYyKSbkQCKI6LzDXMVEnkkHbHRQigdhrgssPgvXXKsO9Ma-yzz1La852DA-vZfjQQr3vkqaUwqBozZ3kWkFeJM-Nq5i7405JewEHD5VODicnZQQVwZgQ; expires=Tue, 04-Aug-2020 04:47:00 GMT; path=/; domain=.google.com; HttpOnly'}
# [('1P_JAR', '2020-02-03-04'),
#  ('NID',
#   '197=NOJtNZ0V6L8qrZp3OlIpJXIfSH_IDZ8CZVOfvGKJHBMWg_N20Tyv_zFGYyKSbkQCKI6LzDXMVEnkkHbHRQigdhrgssPgvXXKsO9Ma-yzz1La852DA-vZfjQQr3vkqaUwqBozZ3kWkFeJM-Nq5i7405JewEHD5VODicnZQQVwZgQ')]

# %% [markdown]
#  ## Part 2
#  Reading a Web Page with Beautiful Soup – following the example starting on page 300-304 of Data Wrangling with Python, use the Beautiful Soup Python library to scrap a web page. The result should be data and output in an organized format. Each of the data entries should be in its own dictionary with matching keys.

# %%
# open and read the page with beautiful soup
from bs4 import BeautifulSoup
import requests

page = requests.get('http://www.enoughproject.org/take_action')
bs = BeautifulSoup(page.content)

print(bs.title)
print(bs.findAll('a'))
print(bs.find_all('p'))
# Out:
# ink main-menu-link item-title" href="https://enoughproject.org/conflicts">Conflicts</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/central-african-republic">Central African Republic</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/congo">Democratic Republic of Congo</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/south-sudan">South Sudan</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/sudan">Sudan</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/upstanders">Upstanders</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders">What Are Upstanders?</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders/frontline">Frontline Upstanders</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders/citizen">Citizen Upstanders</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders/celebrity">Celebrity Upstanders</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/blog">Blog</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/get-involved/take-action">Get Involved</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/get-involved/take-action">Take Action</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/get-involved/join">Join</a>, <a class="menu-link sub-menu-link" href="/events">Events</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/get-involved/donate">Donate</a>, <a class="search" data-nav-search="true"><span class="icon ion-ios-search"></span></a>, <a aria-controls="site-navigation" aria-expanded="false" class="btn-toggle">
# <span class="btn-lines"></span>
# </a>, <a href="https://enoughproject.org/" rel="home">
# <span class="first-logo">
# <img alt="" src="https://enoughproject.org/wp-content/uploads/2017/03/enough_logo_horizontal_nosubtext_white-02-Copy-300x129.png"/>
# </span>
# </a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/about">About</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about">About</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/john-prendergast">Founding Director</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/our-team-2">Our Team</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/the-sentry">The Sentry</a>, <a class="menu-link sub-menu-link" href="#">Past Campaigns</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/conflict-free-campus-initiative">Conflict-Free Campus Initiative</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/past-campaigns/satellite-sentinel-project">Satellite Sentinel Project</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/past-campaigns/rhfc">Raise Hope For Congo</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/past-campaigns/darfur-dream-team">Darfur Dream Team</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/jobs">Jobs</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/about/contact-us">Contact</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/products">Products</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/products/reports">Reports</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/products/videos">Videos</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/media/op-eds">Op-eds</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/products/policy-briefs">Policy Briefs</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/products/policy-one-pagers">Policy One-Pagers</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/products/congressional-testimonies">Congressional Testimonies</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/media/press-releases">Media</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/media/press-releases">Press Releases</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/media/in-the-news">In The News</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/media/op-eds">Op-eds</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/conflicts">Conflicts</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/central-african-republic">Central African Republic</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/congo">Democratic Republic of Congo</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/south-sudan">South Sudan</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/conflicts/sudan">Sudan</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/upstanders">Upstanders</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders">What Are Upstanders?</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders/frontline">Frontline Upstanders</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders/citizen">Citizen Upstanders</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/upstanders/celebrity">Celebrity Upstanders</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/blog">Blog</a>, <a class="menu-link main-menu-link item-title" href="https://enoughproject.org/get-involved/take-action">Get Involved</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/get-involved/take-action">Take Action</a>, <a class="menu-link sub-menu-link" href="https://enoughproject.org/get-involved/join">Join</a>, <a ...
# [<p class="site-title"> <a href="https://enoughproject.org/" rel="home">
# <span class="first-logo">
# <img alt="The Enough Project" src="https://enoughproject.org/wp-content/uploads/2017/03/enough_logo_horizontal_nosubtext_white-02-Copy-300x129.png"/>
# </span>
# </a>
# </p>, <p class="site-title">
# <a href="https://enoughproject.org/" rel="home">
# <span class="first-logo">
# <img alt="" src="https://enoughproject.org/wp-content/uploads/2017/03/enough_logo_horizontal_nosubtext_white-02-Copy-300x129.png"/>
# </span>
# </a>
# </p>, <p>Enough is a project of the New Venture Fund, a 501(c)(3) public charity that incubates new and innovative public-interest projects and grant-making programs. Founded in 2007, Enough focuses primarily on crises in Sudan, South Sudan, eastern Congo, and areas of Africa affected by the Lord’s Resistance Army. Enough seeks to build leverage for peace and justice in Africa by helping to create real consequences for the perpetrators and facilitators of genocide and other mass atrocities. Enough aims to counter rights-abusing armed groups and violent kleptocratic regimes that are fueled by grand corruption, transnational crime and terror, and the pillaging and trafficking of minerals, ivory, diamonds, and other natural resources. Enough conducts field research in conflict zones, develops and advocates for policy recommendations, supports social movements in affected countries, and mobilizes public campaigns.</p>, <p dir="ltr">Tweet at the U.S. State Department and Department of the Treasury as well as the UK’s Foreign Commonwealth Office urging them to use the groundbreaking information in this report to take action in support of peace in South Sudan.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/south-sudan-support-use-robust-financial-tools-actors-highlighted-sentry-report">Take Action Now</a></p>, <p>Contact the joint FCO-DFID Minister for Africa, Andrew Stephenson, MP, and urge him to leverage the information from the recent Sentry report on South Sudan to take action and focus on networks including those where British citizens are reportedly associated with senior government or military officials responsible for human rights violations or abuses in South Sudan.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/tell-uk-address-connections-human-rights-violations-corruption-south-sudan">Take Action Now</a></p>, <p dir="ltr">Help support real change in South Sudan by letting your representative know that building strong leverage and making smart investments in institution building in South Sudan are essential for long-term peace and prosperity.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/south-sudan-financial-tools">Take Action Now</a></p>, <p dir="ltr">Take action and tell Congress that they can help move this agenda forward by introducing strong bipartisan legislation that would help facilitate the imposition of sanctions against Congolese officials, their networks, and external facilitators who have been involved in corruption, human rights violations, and undermining the democratic will of the Congolese people.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/bipartisan-congo-legislation">Take Action Now</a></p>, <p>If managed transparently and responsibly, cobalt revenues could help alleviate poverty in Congo and be a backbone for development. Companies should actively incorporate transparency initiatives into their sourcing protocols in order to address the corruption and human rights abuses linked to cobalt production. Sign these two petitions to companies in the automotive and consumer electronics industries, asking them to become leaders in creating a transparent cobalt trade in Congo.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/companies-leaders-cobalt">Take Action Now</a></p>, <p dir="ltr">Urge the United States, European Union, and United Nations Security Council to investigate and, if appropriate, sanction gold refining and trading companies and their owners that are found to be involved in activities that threaten Congo’s peace, security, or stability through the illicit trade in natural resources.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/conflict-gold-trade">Take Action Now</a></p>, <p>The Enough Project’s 2017 conflict minerals company rankings examine 20 of the largest companies, as defined by market capitalization, in two of the industries which consume the most tin, tungst ...
# C:\Users\Kevin\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Kevin\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# check relationships on the page
# header_children = [c for c in bs.head.children]
# print(header_children)

# navigation_bar = bs.find(id='globalNavigation')

# for d in navigation_bar.descendants:
#     print(d)

#     for s in d.previous_siblings:
#         print(s)

# %%
# open and read the page with beautiful soup
from bs4 import BeautifulSoup
import requests

page = requests.get('http://www.enoughproject.org/take_action')
bs = BeautifulSoup(page.content, 'html.parser')

ta_divs = bs.find_all('div', class_='wpb_text_column')
print(len(ta_divs))

for ta in ta_divs:
    title = ta.h2
    link = ta.a
    about = ta.find_all('p')   
    print(title, link, about)
# Out:
# 8
# None None [<p>Enough is a project of the New Venture Fund, a 501(c)(3) public charity that incubates new and innovative public-interest projects and grant-making programs. Founded in 2007, Enough focuses primarily on crises in Sudan, South Sudan, eastern Congo, and areas of Africa affected by the Lord’s Resistance Army. Enough seeks to build leverage for peace and justice in Africa by helping to create real consequences for the perpetrators and facilitators of genocide and other mass atrocities. Enough aims to counter rights-abusing armed groups and violent kleptocratic regimes that are fueled by grand corruption, transnational crime and terror, and the pillaging and trafficking of minerals, ivory, diamonds, and other natural resources. Enough conducts field research in conflict zones, develops and advocates for policy recommendations, supports social movements in affected countries, and mobilizes public campaigns.</p>]
# None <a href="https://enoughproject.org/get-involved/take-action/south-sudan-support-use-robust-financial-tools-actors-highlighted-sentry-report">Take Action Now</a> [<p dir="ltr">Tweet at the U.S. State Department and Department of the Treasury as well as the UK’s Foreign Commonwealth Office urging them to use the groundbreaking information in this report to take action in support of peace in South Sudan.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/south-sudan-support-use-robust-financial-tools-actors-highlighted-sentry-report">Take Action Now</a></p>]
# None <a href="https://enoughproject.org/get-involved/take-action/tell-uk-address-connections-human-rights-violations-corruption-south-sudan">Take Action Now</a> [<p>Contact the joint FCO-DFID Minister for Africa, Andrew Stephenson, MP, and urge him to leverage the information from the recent Sentry report on South Sudan to take action and focus on networks including those where British citizens are reportedly associated with senior government or military officials responsible for human rights violations or abuses in South Sudan.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/tell-uk-address-connections-human-rights-violations-corruption-south-sudan">Take Action Now</a></p>]
# None <a href="https://enoughproject.org/get-involved/take-action/south-sudan-financial-tools">Take Action Now</a> [<p dir="ltr">Help support real change in South Sudan by letting your representative know that building strong leverage and making smart investments in institution building in South Sudan are essential for long-term peace and prosperity.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/south-sudan-financial-tools">Take Action Now</a></p>]
# None <a href="https://enoughproject.org/get-involved/take-action/bipartisan-congo-legislation">Take Action Now</a> [<p dir="ltr">Take action and tell Congress that they can help move this agenda forward by introducing strong bipartisan legislation that would help facilitate the imposition of sanctions against Congolese officials, their networks, and external facilitators who have been involved in corruption, human rights violations, and undermining the democratic will of the Congolese people.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/bipartisan-congo-legislation">Take Action Now</a></p>]
# None <a href="https://enoughproject.org/get-involved/take-action/companies-leaders-cobalt">Take Action Now</a> [<p>If managed transparently and responsibly, cobalt revenues could help alleviate poverty in Congo and be a backbone for development. Companies should actively incorporate transparency initiatives into their sourcing protocols in order to address the corruption and human rights abuses linked to cobalt production. Sign these two petitions to companies in the automotive and consumer electronics industries, asking them to become leaders in creating a transparent cobalt trade in Congo.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/companies-leaders-cobalt">Take Action Now</a></p>]
# None <a href="https://enoughproject.org/get-involved/take-action/conflict-gold-trade">Take Action Now</a> [<p dir="ltr">Urge the United States, European Union, and United Nations Security Council to investigate and, if appropriate, sanction gold refining and trading companies and their owners that are found to be involved in activities that threaten Congo’s peace, security, or stability through the illicit trade in natural resources.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/conflict-gold-trade">Take Action Now</a></p>]
# None <a href="https://enoughproject.org/get-involved/take-action/demand-the-supply-products-conflict-free">Take Action Now</a> [<p>The Enough Project’s 2017 conflict minerals company rankings examine 20 of the largest companies, as defined by market capitalization, in two of the industries which consume the most tin, tungsten, tantalum, and gold: consumer electronics and jewelry retail. Although a range of industries use these minerals—often referred to as conflict minerals or 3TG—Enough chose to rank these two industries in particular because they have demonstrated the potential to be catalytic in the development of new policies and practices regarding responsible sourcing, and they are also particularly attuned to consumer pressure. These latest rankings acknowledge the steady advances that have been made since Enough conducted its first company rankings in 2010 and expose the considerable and urgent need for more action. Take action by contacting the companies that were ranked in the report and let them know how their conflict minerals policies will impact your future purchasing habits.</p>, <p><a href="https://enoughproject.org/get-involved/take-action/demand-the-supply-products-conflict-free">Take Action Now</a></p>]

# %%
# open and read the page with beautiful soup
from bs4 import BeautifulSoup
import urllib.request

page = urllib.request.urlopen('http://www.enoughproject.org/take_action').read()
bs = BeautifulSoup(page, 'html.parser')

ta_divs = bs.find_all('div', class_='wpb_text_column')
print(len(ta_divs))

for ta in ta_divs:
    print(ta)

# TODO: my get methods are not functional- not sure why 
# use a dictionary for data
# all_data = []

# for ta in ta_divs:
#     data_dict = {}
#     data_dict['title'] = ta.h2.get_text()
#     data_dict['link'] = ta.a.get('href')
#     data_dict['about'] = [p.get_text() for p in ta.find_all('p')]
#     all_data.append(data_dict)

# print(all_data)
# Out:
# 8
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p>Enough is a project of the New Venture Fund, a 501(c)(3) public charity that incubates new and innovative public-interest projects and grant-making programs. Founded in 2007, Enough focuses primarily on crises in Sudan, South Sudan, eastern Congo, and areas of Africa affected by the Lord’s Resistance Army. Enough seeks to build leverage for peace and justice in Africa by helping to create real consequences for the perpetrators and facilitators of genocide and other mass atrocities. Enough aims to counter rights-abusing armed groups and violent kleptocratic regimes that are fueled by grand corruption, transnational crime and terror, and the pillaging and trafficking of minerals, ivory, diamonds, and other natural resources. Enough conducts field research in conflict zones, develops and advocates for policy recommendations, supports social movements in affected countries, and mobilizes public campaigns.</p>
# </div>
# </div>
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p dir="ltr">Tweet at the U.S. State Department and Department of the Treasury as well as the UK’s Foreign Commonwealth Office urging them to use the groundbreaking information in this report to take action in support of peace in South Sudan.</p>
# <p><a href="https://enoughproject.org/get-involved/take-action/south-sudan-support-use-robust-financial-tools-actors-highlighted-sentry-report">Take Action Now</a></p>
# </div>
# </div>
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p>Contact the joint FCO-DFID Minister for Africa, Andrew Stephenson, MP, and urge him to leverage the information from the recent Sentry report on South Sudan to take action and focus on networks including those where British citizens are reportedly associated with senior government or military officials responsible for human rights violations or abuses in South Sudan.</p>
# <p><a href="https://enoughproject.org/get-involved/take-action/tell-uk-address-connections-human-rights-violations-corruption-south-sudan">Take Action Now</a></p>
# </div>
# </div>
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p dir="ltr">Help support real change in South Sudan by letting your representative know that building strong leverage and making smart investments in institution building in South Sudan are essential for long-term peace and prosperity.</p>
# <p><a href="https://enoughproject.org/get-involved/take-action/south-sudan-financial-tools">Take Action Now</a></p>
# </div>
# </div>
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p dir="ltr">Take action and tell Congress that they can help move this agenda forward by introducing strong bipartisan legislation that would help facilitate the imposition of sanctions against Congolese officials, their networks, and external facilitators who have been involved in corruption, human rights violations, and undermining the democratic will of the Congolese people.</p>
# <p><a href="https://enoughproject.org/get-involved/take-action/bipartisan-congo-legislation">Take Action Now</a></p>
# </div>
# </div>
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p>If managed transparently and responsibly, cobalt revenues could help alleviate poverty in Congo and be a backbone for development. Companies should actively incorporate transparency initiatives into their sourcing protocols in order to address the corruption and human rights abuses linked to cobalt production. Sign these two petitions to companies in the automotive and consumer electronics industries, asking them to become leaders in creating a transparent cobalt trade in Congo.</p>
# <p><a href="https://enoughproject.org/get-involved/take-action/companies-leaders-cobalt">Take Action Now</a></p>
# </div>
# </div>
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p dir="ltr">Urge the United States, European Union, and United Nations Security Council to investigate and, if appropriate, sanction gold refining and trading companies and their owners that are found to be involved in activities that threaten Congo’s peace, security, or stability through the illicit trade in natural resources.</p>
# <p><a href="https://enoughproject.org/get-involved/take-action/conflict-gold-trade">Take Action Now</a></p>
# </div>
# </div>
# <div class="wpb_text_column wpb_content_element ">
# <div class="wpb_wrapper">
# <p>The Enough Project’s 2017 conflict minerals company rankings examine 20 of the largest companies, as defined by market capitalization, in two of the industries which consume the most tin, tungsten, tantalum, and gold: consumer electronics and jewelry retail. Although a range of industries use these minerals—often referred to as conflict minerals or 3TG—Enough chose to rank these two industries in particular because they have demonstrated the potential to be catalytic in the development of new policies and practices regarding responsible sourcing, and they are also particularly attuned to consumer pressure. These latest rankings acknowledge the steady advances that have been made since Enough conducted its first company rankings in 2010 and expose the considerable and urgent need for more action. Take action by contacting the companies that were ranked in the report and let them know how their conflict minerals policies will impact your future purchasing habits.</p>
# <p><a href="https://enoughproject.org/get-involved/take-action/demand-the-supply-products-conflict-free">Take Action Now</a></p>
# </div>
# </div>

# %% [markdown]
#  ## Part 3
#  Web scraping with Selenium - Follow along with your book starting on page 318-329 of Data Wrangling with Python. At the end of the exercise, you should be able to go to a site, fill out a form, submit the form, and then scroll through the results with the code you wrote. Make sure to submit the code and your output.

# %%
from selenium import webdriver

browser = webdriver.Chrome()

browser.get('http://www.fairphone.com/we-are-fairphone/')
browser.maximize_window()

content = browser.find_element_by_css_selector('li.feed-item') 
print (content.text)
all_bubbles = browser.find_elements_by_css_selector('li.feed-item') 

for bubble in all_bubbles: 
    print (bubble.text)
# Out:
# Hello Fairphone 3 #Fairphone @Fairphone thinking about our planet and their customers.
# Reply
# Retweet
# Like
# 2 Feb 2020
# Hello Fairphone 3 #Fairphone @Fairphone thinking about our planet and their customers.
# Reply
# Retweet
# Like
# 2 Feb 2020
# ONLY 2 SLEEPS TO GO!!!
# •
# •
# •
# #CPCFIRE launches CLAPHAM on this coming MONDAY 🍫💥🤯🎟👑👌🥳🔥🙏👊🧡
# (Tkts on link in bio)
# •
# •
# Dont forget to grab your ticket and/ or enter our competition. We'll see you at @theclaphamnorth feat. @riverssr1 and LOUD open mic Chocolate Eaters! •
# •
# •
# #openmic #chocolate #cpc #openmic #monday #clapham #london #loud #seedandbean #wearefairphone #fairphone
# 021
# Wer von euch nutzt bereits das Fairphone 3? 📱
# ______
# #fairphone #sustainability #fairphone3
# 819
# Impressions from #changenow2020
#
# #biomaterials #fishscaletiles #greenmood #biodiversity #impactecosystem #naturalaccoustics #grandpalais #parisfrance #smartcity #iot #algae #algaeplastic #sustainable #ai #1000solutionstochangetheworld #fairphone #commown @commown @fairphone @sla_architects @green_mood_pl
# 027
# .⁦@Orange_France⁩ présent au #ChangeNOW2020 summit avec le #Fairphone.
# Reply
# Retweet
# Like
# 30 Jan 2020
# .@basvanabel from @Fairphone to hop on stage in a few minutes at @changenow2020 to talk circular economy and fairer tech!
# #ChangeNOW2020 #fairphone #planetboundaries
# Reply
# Retweet
# Like
# 30 Jan 2020
# #amaryllis #wächstundgedeiht #blüte #knospenspringenauf #blühen #kleinedinge #littlethings #liebedasleben #nature #hobbyphotography #fairphone
# 028
# Trees are 300 million year old prehistoric creatures. Humanity is only 300,000 years old.
# Les arbres sont des créatures préhistoriques de 300 millions d'années. L'humanité n'a que 300 000 ans. .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 030
# Tuomaksen Reiluluurista tulikin Kuusiluuri. Kuusniemelle varmaankin ihan sopivaa. :D #fairphone
# 120
# Feels like my mobile camera was as impressed with Monet as I was. Tech impressionistic view of Paris
#
# #paris #eiffeltower #fairphone #museelorangerie
# 170
# Oser le changement ! #fairphone #samebutdifferent #ouicycle #socialresponsability
# 012
# The Fairphone 3 is the new sustainable smartphone 🌍 Made from fairly sourced and recycled materials this is the phone that cares for people and planet. #Sure #GetMoreFromSure #DareToCare #Fairphone #Guernsey
# 08
# Happy Birthday to me 💚💚💚 #fairphone #fairphone3 #besterehemann #itsmybirthday #fairtrade #wearethechange #reparierenstattwegwerfen #sustainability #stoffwindelglück
# 716
# Quelque chose se prépare ici... Je peux déjà vous dire qu'il s'agit d'un nouveau concept que je teste pour la première fois, et qui impliquera une chanson de l'album Avant/Après. J'ai longtemps hésité à faire cette vidéo, ne sachant pas si c'était une idée marrante ou un peu nulle - comme la plupart de mes idées, en fait ! Mais cela faisait longtemps que j'en avais envie, alors j'ai décidé de me lancer. Ce sera la première d'une nouvelle série sur ma chaine YouTube. Rendez-vous dimanche à 17h ! .
# .
# .
# #ootv #outfitofthevideo veste @armedangels chez @wonderlooop et robe de #secondemain chez Boutique Jipex (Bruxelles) #organicmakeup @lilylolouk @zaomakeup_official @couleurcaramelofficiel @drhauschkafrance .
# .
# .
# #youtube #youtubeuse #chanteuse #videaste #belgianmusic #aci #autricecompositriceinterprete #chanson #fairphone #slowfashion #moderesponsable #modeethique #maquillagebio #avantapres
# 012
# 🇫🇷 Une très belle (et vieille) mosquée à l'architecture très particulière (Karakol).
# .
# 🇬🇧 A very beautiful (and old) mosque with very particular architecture (Karakol).
# .
# #Kyrgyzstan #Kirghizistan #Karakol #mosque #mosquee
# .
# #voyage #travel #Terre #Earth #inspiration #environment #tourdumonde #rtw #worldtour #green
# .
# 📷 avec #fairphone @fairphone
# 020
# Mood of the day. ☁️ #mood #fairphonephoto #fairphone #fairphonepicture (unbezahlte Werbung)
# 150
# Some people know how to make me feel fancy... Authority Magazine kindly offered to interview me as one of their "pop culture's rising stars"😎, and look at the picture I found in the article! ⠀
# .⠀
# Topics we covered:⠀
# - My journey into becoming an actress (and my funniest mistake 🤡)⠀
# - Current projects & industry "hacks"⠀
# - Diversity in entertainment, what "doing good" means and my dream to work with Ben Affleck on his upcoming film about DRC 🇨🇩⠀
# . ⠀
# Link in my story, share a clap to share the love!⠀
# .⠀
# 🇫🇷 Certaines personnes savent comment me faire prendre la grosse tête... Authority Magazine m'a gentiment interviewée comme "pop culture's rising star", et regardez la photo que je trouve dans l'article !⠀
# .⠀
# Les sujets que nous avons abordés :⠀
# - Mon parcours pour devenir actrice (et ma plus drôle erreur🤡)⠀
# - Projets actuels et conseils sur l'industrie du divertissement⠀
# - Questions sur la diversité, les actions pour rendre notre monde meilleur, et mon rêve de travailler avec @benaffleck sur son film à venir sur la RDC🇨🇩
# .⠀
# Lien dans ma story : tapez un clap pour taper un soutien ! .⠀
# Feeling like a #risingstar #raisehopeforcongo #drc #fairphone #buyfairtrade
# 28175
# Hêtre pourpre en hiver
# #CopperBeech
# .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 026
# 🇫🇷 Au Kirghizistan, difficile de trouver une poubelle pour jeter ses déchets. Le CBT (Community Based Tourism Association) d'Arslanbob en a posé quelques unes dans la ville : chouette initiative !
# .
# 🇬🇧 In Kyrgyzstan, it is difficult to find a trash can. The CBT (Community Based Tourism Association) of Arslanbob has installed some in the city: great initiative!
# .
# #Trash #Poubelle #Kyrgyzstan #Kirghizistan #arslanbob #cbt
# .
# #voyage #travel #Terre #Earth #inspiration #environment #tourdumonde #rtw #worldtour #green
# .
# 📷 avec #fairphone @fairphone
# 021
# #Viburnum farreri blooms during winter
# (Les viornes fleurissent en hiver) .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 032
# L'aventure #fairphone continue!
# Mon fairphone2 repart pour être recyclé... 5 ans de vie commune, de mésententes, de rabibochages... Mais je ne regrette rien! Vive mon #fairphone3 !
# #Changeisinyourhand
# 212
# Et voici le Fairphone !!
# La seule marque eco responsable pour smartphone.
# Fabriqué à partir de matériaux recyclés et équitables, plus une conception modulaire et réparable sois même.
# 64go de stockage, Android 9 pure.
# #ecoreflex #ecoresponsable #fairphone #fairphone3 #recyclage #paris #paris10 #cashexpress #france #smartphone
# 025
# I got my @fairphone today! 🎊 ❤️ #fairphone #changeisinyourhands #fairtrade
# 218
# Ed eccoli qui i nuovi telefoni di Vanilla!
# @fairphone è il telefono che osa essere equosolidale.
# Ha a cuore le persone e l'ambiente: migliora le condizioni delle persone che lo producono e utilizza materiali che fanno bene al pianeta.
#
# Siamo convinti che ogni scelta che facciamo faccia di noi i protagonisti del cambiamento e che il modo (e il cuore) in cui si producono le cose sia importante.
# .
# .
# .
# #fairphone #digitalcreators #webagency #webmarketing #webagencylife #vanillamarketing #webagencyancona #makethechange #equosolidale #vanilladigitalcreators
# 038
# Ich hab eh ein neues Smartphone gebraucht 😉 #fairphone #fairphone3 #smartphone
# 016
# Leaving Paris today!
# It was worth the hustle and the whirlwind to get there. Inspired by global change leaders standing up for what is right, designing new technology and ecosystems for a transformative future - the time to change is now! The time to act is now! @changenow_summit #changenow2020
# Huge thank you for all those who continue to believe in my mission for a brighter greener Tanzania @thekiliproject and working with @green.stand to bring more transparency to the tree industry but also by empowering some of the worlds poorest to earn an income through growing trees.
# Blessed beyond measure #passion #purpose #change
# Interesting reflection:
# Met so many who are serious about change, rapid transformation to fix our broken world. a backlash and outspoken criticism for Amazon and Google not paying their taxes (amongst other things) and an ask to use @ecosia as our search engine (we have an interesting partnership coming up with them!) , a call to boycott Apple products and use a #fairphone alternatives, conversations with @mudjeans founder on sustainable fashion, understanding more about @bcorporation @bcorpeurope @bcorpuk and to top it off an inapirarional talk by Satish Kumar from @schumachercollege #transformation #sustainabity #changemaker #vision2020 and beyond #newworld #inclusion #shapers - #tanzania and #kenya I am coming back! #eastafricangirl committed to change.
#
# I AM GRATEFUL
# 131
# COMUNIDAD FAIRPHONE
# El próximo jueves 6 nos reunimos usuarios y amigos de Fairphone en Ecolectia para interecambiar experiencias, debatir ideas en torno a la tecnología ética y compartir una taza de café y té
# ¿Te animas?
# _____________
# FAIRPHONE COMMUNITY
# On Thursday 6, we meet Fairphone users and friends at Ecolectia to exchange experiences, discuss ideas about ethical technology and share a cup of coffee and tea
# Dare to care?
# _____________
# #Barcelona #Fairphone #DareToCare #BCN #Ecolectia #fairtrade #comerciojusto
# 059
# 2016 haben wir den Laden hier übernommen und einen guten Start gehabt . Jetzt sind es schon 4 Jahre her , wir sind glücklich euch als Kunden zu haben und weiterhin auf der Venloerstraße aktiv zu bleiben .
# Wir haben alle Modelle vorrätig und immer zu Top Preisen ❤️ #since2016 #seit2016 #angebot #treue #köln #ehrenfeld #venloerstraße #handyladen #apple #samsung #huawei #google #lg #sony #fairphone
# 132
# Carsten Waldeck produziert ein Smartphone, das nachhaltig ist. Sein Mantra: Mensch first! Dabei wird auf faire Löhne und Arbeitszeiten geachtet. Link in Bio; unsere Nummer 2 👉🏼 „5 Ideen, die dich zum Helden machen“
# .
#
# Abkürzung? 👉🏼 https://win.gs/2OcsTc3
# . 📸 @shiftphones .
#
# #wingstoideas #fairphone #betterfuture #weareallinthistogether #visionäre #pioniere #mystartupmoment #inspiringideas #inspiringpeople
# 126
# L'oca che le mele
# non cura del futuro.
# E la tara del fuco che aspetta
# si libri la regina
# per poter un giorno o un'ora
# dell'arnia essere il re.
# #lego #legos #legominifigures #legominifigure #legostagram #instatoys #instalego #brickworld #bee #fuco #crossword #blackandwhite #fairphone #futuro #libri #arnia #oca #re #relax
# 120
# Not a bad place to be on stage :-) #changenowsummit #paris #fairphone
# 453
# 𝐆𝐎𝐎𝐆𝐋𝐄 𝐍𝐄𝐒𝐓 𝐇𝐔𝐁. 𝐖𝐈𝐄 𝐅Ü𝐑 𝐃𝐈𝐂𝐇 𝐆𝐄𝐌𝐀𝐂𝐇𝐓. Komm bei uns im Shop vorbei und teste! Was kann es denn alles? Hier sind schonmal ein paar Fakten:
# ⠀
# 𝗘𝗶𝗻 𝗱𝗶𝗴𝗶𝘁𝗮𝗹𝗲𝗿 𝗕𝗶𝗹𝗱𝗲𝗿𝗿𝗮𝗵𝗺𝗲𝗻 𝗳ü𝗿 𝗮𝗹𝗹 𝗗𝗲𝗶𝗻𝗲 𝗘𝗿𝗶𝗻𝗻𝗲𝗿𝘂𝗻𝗴𝗲𝗻.
# Lass Dir alle deine Google Fotos anzeigen oder sieh Dir die schönsten und neuesten Fotos Deiner Liebsten an – ein Sprachbefehl genügt.
# ⠀
# 𝗩𝗼𝗹𝗹𝗲 𝗞𝗼𝗻𝘁𝗿𝗼𝗹𝗹𝗲 ü𝗯𝗲𝗿 𝗗𝗲𝗶𝗻 𝗦𝗺𝗮𝗿𝘁 𝗛𝗼𝗺𝗲.
# Tausende kompatible Geräte wie Lampen, Kameras oder Fernseher lassen sich über ein einziges Dashboard per Sprachbefehl steuern.
# ⠀
# 𝗛𝗶𝗹𝗳𝗲 𝗽𝗲𝗿 𝗦𝗽𝗿𝗮𝗰𝗵𝗯𝗲𝗳𝗲𝗵𝗹 – 𝗱𝗮𝗻𝗸 𝗚𝗼𝗼𝗴𝗹𝗲 𝗔𝘀𝘀𝗶𝘀𝘁𝗮𝗻𝘁. 𝗚𝗼𝗼𝗴𝗹𝗲 𝘀𝘁𝗲𝗵𝘁 𝗗𝗶𝗿 𝘇𝘂𝗿 𝗦𝗲𝗶𝘁𝗲.
# Du brauchst Hilfe beim Kochen, willst mehr über ein Unternehmen in der Nähe erfahren oder wissen, wie Deine Lieblingsmannschaft gespielt hat? Frag einfach Google Assistant und erhalte alle Antworten auf Nest Hub.
# ⠀
# 𝗛𝗶𝗹𝗳𝗿𝗲𝗶𝗰𝗵𝗲 𝗩𝗶𝗱𝗲𝗼𝘀 𝗮𝘂𝗳 𝗬𝗼𝘂𝗧𝘂𝗯𝗲 𝗮𝗻𝘀𝗲𝗵𝗲𝗻.
# Manches lässt sich besser zeigen als erklären. Sag einfach "Ok Google, wie schneide ich eine Ananas?" und schon kannst Du dir ein Anleitungsvideo dazu ansehen.
# ⠀
# 𝗩𝗶𝗱𝗲𝗼𝘀 𝘂𝗻𝗱 𝗠𝘂𝘀𝗶𝗸 𝘃𝗼𝗻 𝗬𝗼𝘂𝗧𝘂𝗯𝗲 𝗮𝗯𝘀𝗽𝗶𝗲𝗹𝗲𝗻.
# Dank der Lautsprecher kannst Du Songs und Videos von YouTube Music mit kristallklarem Sound erleben.
# ⠀
# Oder höre Musik über Spotify, Deezer und TuneIn. Und das alles kostenlos.
# ⠀
# 𝗚𝘂𝘁 𝗼𝗿𝗴𝗮𝗻𝗶𝘀𝗶𝗲𝗿𝘁 𝗱𝘂𝗿𝗰𝗵 𝗱𝗲𝗻 𝗧𝗮𝗴. 𝗘𝗶𝗻 𝗠𝗼𝗿𝗴𝗲𝗻 𝗴𝗲𝗻𝗮𝘂 𝗻𝗮𝗰𝗵 𝗗𝗲𝗶𝗻𝗲𝗺 𝗚𝗲𝘀𝗰𝗵𝗺𝗮𝗰𝗸.
# Dank Voice Match kannst Du bequem in den Tag starten.
# ⠀
# Sag einfach "Ok Google, guten Morgen" – und schon hast Du alles im Blick, was Du brauchst: Deine Termine, den Weg zur Arbeit oder Erinnerungen. Mit Nest Hub kannst Du sogar Deine eigenen Abläufe erstellen. "
# ⠀
# 𝗛𝗶𝗹𝗳𝗲 𝗱𝗶𝗿𝗲𝗸𝘁 𝗮𝘂𝗳 𝗱𝗲𝗺 𝗦𝘁𝗮𝗿𝘁𝗯𝗶𝗹𝗱𝘀𝗰𝗵𝗶𝗿𝗺 – 𝗳ü𝗿 𝗷𝗲𝗱𝗲 𝗟𝗲𝗯𝗲𝗻𝘀𝗹𝗮𝗴𝗲.
# Du siehst auf einen Blick, was als Nächstes ansteht oder wie Du am schnellsten zur Arbeit kommst.
# ⠀
# Doch das ist nicht alles: du kannst empfohlene YouTube-Videos abspielen, Rezepte ansehen oder den Timer stellen – alles kein Problem.
# 110
# 🔺 Conoce el nuevo #Fairphone 🔻
#
# El nuevo Fairphone 3 es un móvil ético y #sostenible con su método de fabricación respetuoso con la naturaleza y los derechos humanos. Solo en @vodafone_es
#
# #unfourtel #telecomunicaciones #empresas #vodafone #vodafoneespaña #Conectividad
# Reply
# Retweet
# Like
# 27 Jan 2020
# L'hiver les #arbres dorment
# Trees are sleeping in winter...
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 019
# #startthedaywithawalk #frischeluft #kalt #morning #nebel #rhein #flussbett #wenigwasser #spazieren #kopffrei #lernzeit #nature #dorfkind #fairphone
# 036
# Place des Vosges l'hiver
# (In winter)
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 025
# The Fairphone 3 is the new sustainable smartphone 🌍 Made from fairly sourced and recycled materials this is the phone that cares for people and planet. #Sure #GetMoreFromSure #DareToCare #Fairphone #IOM #IsleofMan
# 04
# Fairphone 3: goede duurzame insteek
#
# #duurzaam #fairphone @Fairphone
#
# ct.nl/reviews/fairph…
# Reply
# Retweet
# Like
# 24 Jan 2020
# Game of thorns. 📌 #dornen #thorns #brightred #redalert #fairphone #fairphonephoto #fairphoneshot (unbezahlte Werbung )
# 048
# #Trees are our friends. We wouldn't be here, we wouldn't breeze without them...
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 017
# Ikväll på @etcbokcafestockholm: Följ med på en föreläsning om elektronikindustrins mörka baksida.
# @fairphone #fairphone #teknik #mobil #klimat
# 0103
# I finally got my #fairphone #changeisinmyhands 😄
# 04
# Can't not... #sunset #beach
# #beachlife #pier #ridetime #silhouette #fairphone #fp2
# 162
# Smartphone security update report (March 2019) Long-term comparison of the best protected smartphones with security updates. Study the past if you would define the future. #Google #Apple #WindowsPhone #Samsung #FairPhone #MobileSecurity #PlannedObsolescence
# Reply
# Retweet
# Like
# 20 Jan 2020
# My Photography
# #photography #art #creativity #morning #sky #scenic #theworldisacanvas #scenery #amateur #happy #interests #fairphone Thank you @fairphone for making so much possible.
# 017
# 🇫🇷 Au Kirghizistan, faut être patient !
# .
# 🇬🇧 In Kyrgyzstan, be patient!
# .
# #Kyrgyzstan #Kirghizistan #beef #sheep
# .
# #voyage #travel #Terre #Earth #inspiration #environment #tourdumonde #rtw #worldtour #green
# .
# 📷 avec #fairphone @fairphone
# 028
# Weird how it happens, sometimes.. Two days ago I had a little exchange with an insta-acquaintance about cell phones (Hi E! :) ). I’m not really into phones and stuff in that sense, but they had asked for advice on a new phone since their now-one was acting up. So I wrote and suggested they’d look into Fairphone...and we started talking a bit.
# 📞
# Yesterday morning then, on my walk to the bus, I dropped my own phone to the ground. And...it just stopped working - the screen being unresponsive to touch. I started thinking about all the stuff I had on it, not backed up...and probably didn’t look too happy to the people driving by in their cars (so many cars, there were so many cars out that morning).
# 📞
# Luckily enough the phone woke up and I could email myself the most important unbacked-up things I found. Which felt like I had received a bonus gift or something, because later again the phone began to live its own life - starting a facetime-call when I wasn’t even in the room (I came back to see my partner’s surprised face on the screen and then we had a minute of “Umm hi??” “Did you call me?” “No, you called me??” “Weeeeiirrrd!” until my phone hung up on us and jumped into old text messages instead, doing stuff completely on its own...and I thought it best to just shut it down completely before it would start sending out random Hello:s in the world.
# 📞
# So - now I’m charging my good old Fairphone again* to hopefully use until I’ve figured out where to find a new-old phone. Fingers crossed it still works, after all this time put aside! 💛
# 📞
# And, to the important point: for anyone looking for a phone (or anyone just wanting to know more about the tech-industry and get inspired by people out there providing alternatives to the less-than-great business as usual) - check @fairphone out! Conflict minerals and child labor are otherwise two things to research more when the itch for the next “newest” gadget sets in. 💚
# 33
# Découvrez des actions pour un usage tech éco-responsable
# 👉 wp.me/p9daJA-1eO
#
# Sur le #FairPhone, on peut remplacer tous les composants et ainsi conserver son #smartphone plus longtemps. C'est à la fois éthique, écologique et économique.
#
# #Tech4Planet #EcoResponsable #DEEE
# Reply
# Retweet
# Like
# 17 Jan 2020
# Neu bei o2 #new #fairphone #fairphone3 #o2 #telefonica #telefonicagermany #werbung
# 011
# 🇫🇷 Insolite : un complexe abandonné avant la fin de sa construction. Aalam Ordo devait devenir un lieu d'échange, de culture, de transmission du savoir ancien auprès des nouvelles générations.
# .
# 🇬🇧 Unusual: a complex abandoned before the end of its construction. Aalam Ordo was to become a place of exchange, culture, transmission of ancient knowledge to new generations.
# .
# #Kirghizistan #Kyrgyzstan #AalamOrdo
# .
# #voyage #travel #Terre #Earth #inspiration #environment #tourdumonde #rtw #worldtour #green
# .
# 📷 avec #sony #alpha6300 @sonyalpha
# .
# 📷 avec #fairphone @fairphone
# 022
# Es wird spannend. www.reviewmirror.net #fairphone #reviewmirror
# 09
# Ich bin gespannt #fairphone
# Reply
# Retweet
# Like
# 1 Feb 2020
# Got my phone fixed!
#
# I've had this phone for nearly two years and it's been blighted with charging issues for the last few months. It got to a point it almost wouldn't charge.
#
# I took it to a Restart Party @restartproject a couple of weeks ago and was told that they couldn't help me because the screen has to be removed in order to fix the charging port and yet it is glued tight! In a weak moment I even started browsing for at new phone 🙈 but at the end I decided to take it to a repair shop.
#
# It wasn't a cheap repair at all at the end (and I was told I had to be prepared the screen might bust when they tried to unglue it which they wouldn't cover for), but now I have a perfectly fine phone once again.
#
# From this whole experience, I have learnt a few new things which I thought I'd share. First is that there is a smartphone repairability list by @ifixit - included are a number of new and popular models and their repairability. I never took repairability into account when I purchased phones before, but if I was to buy one now I'd definitely check out the repairability score.
#
# This is the link:
# https://www.ifixit.com/smartphone-repairability
#
# The second thing I learnt is that there is an ethical and extremely repairable brand of smartphone in the market (I was told this by the lady at the Restart event). @fairphone is a company that sources materials sustainably and advocating workers' welfare. Also they don't include "useless" things with their phones such as earphones and chargers (I am sure everyone has a drawer full of old ones right?). ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# Always try to get your phone repaired before resorting to buying a new one. Sometimes you'd be surprised at what small issue is causing your phone to play up (e.g. fluff from clothes can get stuck in charging port, though that wasn't my phone's problem, it was properly busted!). Also, there is a number of reputable websites that sell refurbished smartphones so it's definitely worth looking up when the time comes to replace one.
#
# Last but not least, don't forget to dispose of your old phones and accessories responsibly!
# 331
# Ink or tree ?
# Encre ou arbre ?
# .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 122
# We need to change the way we think & behave, adapt our journey. We have become alienated from the way things are made. We need to improve - fairness & sustainability -how products are made & used
# #Quantis #Fairphone #LowTechLab #ClarinsGroup #ExtensionRevellionUk #ChangeNow2020
# Reply
# Retweet
# Like
# 30 Jan 2020
# Yesterday I fixed my phone camera by squeezing the phone next to the camera. I'm glad I read passed "take your phone apart, clean it and put it back together. #fairphone #menddontspend #kansjälv #diy #diyelectronics #fairphone2
# 212
# It’s here! The phone made with care for people and the planet. #DareToCare with Fairphone. A fairer phone for a fairer world 🌍 📱 #fairphone #sustainable #recycle #mobilephone #carefortheplanet #planetearth #smallbusiness #sustainability #ecofriendly #zerowaste #sustainable-living #environment #climatechange #recycle #nature #gogreen #eco #savetheplanet #reuse #green #design #fashion #innovation #earth #climateaction
# 014
# Herzlich Willkommen bei uns in der Digitalen Welt von mobilcom-debitel💚
# ⠀
# Wir sind bei allen Fragen jederzeit für dich da.
# 134
# #fairphone
# 212
# mise en abime imparfaite. Une image de fairphone sur un fairphone pris en photo par un asus zenfone. #echec #fairphone #mavieestnulmaiscapourraisetrepire
# Reply
# Retweet
# Like
# 25 Jan 2020
# #amaryllis #blüte #knospe #blühen #kleinedinge #littlethings #liebedasleben #nature #hobbyphotography #fairphone
# 026
# Das Fairphone 3 überzeugt wie seine Vorgänger durch Nachhaltigkeit 💙
# ⠀
# Ein Smartphone, das sich traut Fair zu sein. Mit Rücksicht auf Mensch und Umwelt hergestellt. 💚
# ⠀
# Was haltet ihr vom Fairphone? 📲
# ✔️
# •
# •
# •
# •
# •
# #fairphone #fairphone3 #android #fair #smartphone #nachhaltigkeit #earth #greenearth #inspiration #grün #nachhaltig #wearefair #recycelt #recycle #design #umweltfreundlich #umweltschutz #fairness #googleplay #neumarkt #mobilcomdebitelneumarkt #mobilcomdebitel #neumarktinderoberpfalz #postbauerheng #berg #deining #parsberg #regensburg #mühlhausen #allersberg
# 437
# Les #arbres inspirent la vie
# Trees inspire life
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 028
# Keeping warm in my Elina jacket very kindly knitted by @lesleywild in @rowanyarns Colourspun (now sadly discontinued). It's a great pattern and could be worked in any standard DK. Also, inadvertently promoting my #fairphone from @thephonecoop
# #knitting #knittersofinstagram #yarn #yarnshop #rowanyarn #chippingnorton #shopsmall #shoplocal #lovemiddlerow
# 049
# Bra stämning ikväll när Kent Vilhelmsson från ETC berättade om elektronikindustrins mörka baksidor. Tack alla som kom och lyssnade och ställde kloka frågor!
# @fairphone #fairphone #fairtrade #klimat #mobil
# 022
# Unser Planspiel zu "Menschenrechten in der Lieferkette am Beispiel Smartphone" ist fertig aufgeschrieben und kann gerne von euch genutzt werden!
# Danke für's fleißige Mitarbeiten
# @ann_kathrein
# @maryxsxo
# @joachim_cfk
# www.anders-handeln.org/alles-was-recht-ist/
#
# #andershandeln #menschenrechte #lieferkettengesetz #initiative #alleswasrechtist #evangelischejugend #evjugend #setzdichein #human #humanrights #ekjbnf #smartphone #fairphone #shifthappens #einewelt
# 048
# 🇫🇷 Souvent faut savoir abandonner son confort. En même temps, on n'a pas besoin de plus !
# .
# 🇬🇧 Often you have to know how to give up your comfort. Actually, we don't need more!
# .
# #Kyrgyzstan #Kirghizistan #toilettes #toilet
# .
# #voyage #travel #Terre #Earth #inspiration #environment #tourdumonde #rtw #worldtour #green .
# 📷 avec #fairphone @fairphone
# 521
# Filtered Silhouette
#
# My photography partly possible because of @fairphone.
# #photography #documentinglife #life #achievement #walking #evening #interestingfilter #nottruetoreality #fairphone
# 08
# This week’s WEPproved is the Fairphone! Our board member Christelle recently bought one and is very happy with it!
# #wurlife #ganwageningen #fairphone #sustainablephone #environment #wageningenuniversity
# 244
#
# Day 17: Stari Bar, Montenegro 15/10/19 (second batch)
#
# #cutestpuppyever #dogsofinstagram #poser #vintagebikes #gorgeousday #sunshine #exploring #fortress #contrasts #clocktower #silhouette #sunset #staribar #montenegro #fairphone2 #fairphone #someonebuymethenextone #gluck
# 020
# My friend has just got a #fairphone, really amazing different way of consuming electronics #ActNow
# Reply
# Retweet
# Like
# 17 Jan 2020
# What if you could buy a phone that will last five years, can be easily repaired and is made as ethically as possible?
#
# We'll let our industrial design lead James Barber answer that one :)
# 17235
# #Fairphone
#
# Sur #iFixIt noté 10/10 en réparabilité!
#
# 1 Téléphone modulaire (vente des modules cassés) contre l'obsolescence programmée et #ethique.
# Reply
# Retweet
# Like
# 17 Jan 2020
# Découvrez des actions pour un usage tech éco-responsable
# 👉 wp.me/p9daJA-1eO
#
# Sur le #FairPhone, on peut remplacer tous les composants et ainsi conserver son #smartphone plus longtemps. C'est à la fois éthique, écologique et économique.
#
# #Tech4Planet #EcoResponsable #DEEE
# Reply
# Retweet
# Like
# 16 Jan 2020
# Discarded laptops, mobile phones and electronic goods are now the world’s fastest growing waste problem, with a 2017 report finding waste from discarded electronics up eight per cent in two years, and only 20 per cent being recycled.⁠
# .⁠
# Dutch smartphone brand @fairphone is challenging our cultural demand for the latest and greatest in favour of the planet. With a focus on responsibly sourced and conflict-free materials, the company positions itself as a rare outlier in the smartphone industry by building what it calls “long-lasting and sustainable phones" that are modular in design and can be easily repaired and upgraded without having to chuck away the entire devise into landfill... That's pretty dope ♻️👍⁠
# .⁠
# Photo c/o @fairphone⁠
# .⁠
# .⁠
# .⁠
# #fairphone #recycle #waste #landfill #renewable #responsiblysourced #ethicaldesign #changemakers #changemaker #fortheplanet #saveourplanet #reducewaste #wasteland #innovation #pioneer #dogood #createchange #tech #reusable #ethicallymade #ethical #ethicalbrand #technology #designinspiration #creativeinspiration #protectourplanet #smartphonerepair #smartphone #technews #techie
# 010
# This car is almost 28 years old, its name is Hubert and it's wearing its fourth star. ⭐⭐⭐⭐😅 #oldcars #classiccars #youngtimer #mercedes #mercedesbenz #mercedes124er #mercedesw124 #stillrolling #fairphone #fairphone3 #fairphonrphoto #fairphonefoto (unbezahlte werbung)
# 240
# Quand tout est flou MAIS quand on a confiance en la vie, l'énergie de la ville, c'est (presque) comme celle de la nature (et oui... avant les portes ouvertes officielles de l'espace petite herboristerie, il me faudra remplacer micro et appareil photo du Fairphone- il y a des appels que je n'entends même pas... Les excuses !) Photo de Timea qui est pourtant bon photographe. Et oui je suis encore terrifiée d'être prise en photo... Quelles plantes aident avec la peur et anciens traumas? Il y en a tant; elles sont tellement généreuses et attendent juste d'aider. Ma préférée du moment qui fait que cette photo existe, même floue, c'est une plante qui nettoie et enracine dans la confiance en même temps: l'angélique... En teinture mère, peut être prescrite et remboursée en Suisse, par l'assurance de base. Plus d'info? Vous savez vers qui vous tourner. #angelique #herboristerie #herbalism #peurs #guérisons #healings #fears #2020 #geneveterroir #geneve #fairphone #cathedrale #vertiges #espacepetiteherboristerie #angelique #angelicaarchangelica #plantesmedicinales #protocolespeurs #phythotherapie #soinsnaturels
# 015
# ❇❇❇❇❇ Poésie du quotidien ❇❇❇❇❇ Une chambre, la lumière qui passe à travers la fenêtre et vient se cogner au vieux miroir pour se poser délicatement sur ma main.
# .
# Prêter son attention aux petits détails, aux rayons de lumière, à la poussière, ça rend la vie si belle! ✨ .
# Et toi, quel détail a embelli ta journée ?
# .
# .
# .
# .
# .
#
# #rainbow
# #poetry
# #lifestyle
# #fairphone2
# #fairphone
# #mood
# 366
# We need to change the way we think & behave, adapt our journey. We have become alienated from the way things are made : we need to improve - fairness & sustainability- how products are made & use
# #Quantis #Fairphone #LowTechLab #ClarinsGroup #ExtensionRevellionUk #ChangeNow2020
# Reply
# Retweet
# Like
# 30 Jan 2020
# Tree branch like an ink stream crossing the photo
# Une branche comme un filet d'encre traversant la photo.
# .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 025
# Trees bring us closer to the sky
# Les arbres nous rapprochent du ciel... .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 029
# Bei allen fragen Rund um Smartphone, Tv, DSL, Tarife sind wir da für dich ❤️✌🏽.
# 114
# Vers online de #boekbespreking #recensie van het #boek van #Stikker. Surf er zelf naar #zinvollerleven.nl of klik de linkinbio aan.
#
# Het #internet is stuk volgens #internetpionier #MarleenStikker
# Het internet is in handen van data slurpende #big tech bedrijven. Tijd om 'smart' om te gaan met internet
#
# #zomergasten #dewaag #waag #fairphone #privacy #smart #gegevens #gegevensbescherming #data #digibewust #platformeconomie #google #facebook #amazon #apple #economie #internetgebruik #bigbrother📱💻🔍
# 09
# #fairphone in the Design Museum
# 18
# The Fairphone 3 is the new sustainable smartphone 🌍 Made from fairly sourced and recycled materials this is the phone that cares for people and planet. #Sure #GetMoreFromSure #DareToCare #Fairphone #Jersey
# 05
# The most colourfull door in my city! 🖍️🚪🎨 @stillill_freiburg
# f/1,8 1/152 4,36 mm ISO200
#
# #door #colourfull #colourfullife #photooftheday #fairphone #fairphone3 #stickers #grafitti #old #city
# 053
# 📱🌱 Rundum fair und ökologisch nachhaltig, das ist das Ziel - auch bei Elektrogeräten.
# * Unbezahlte WERBUNG zwecks Namensnennung * Fairphone 1 war mein 1. Smartphone, ganz gut insg., nur irgendwann veraltet. Als mein Akku kaputt war und ich ihn NICHT austauschen konnte, da sie den Support dafür einstellten, war ich etwas... enttäuscht. 😅 Next Try: Shiftphone! Made in Germany / China! Die Preise starten bei 444€. Ich finde das Shiftphone gut, das kl. Unternehmen gibt sich viel Mühe, sie zahlen faire Löhne, versuchen die Handelswege transparent zu gestalten und auf Rohstoff-Zertifikate zu achten. 🙃 Das Shiftphone wurde modular gebaut, sodass man defekte oder veraltete Teile einfach selbst austauschen kann. Wenn man über kleinere Macken hinwegsieht (3 x in 2 Jahren ist mein Akku zu heiß geworden und manchmal fungiert mein Ohr als Finger und plötzlich wird der Lautsprecher aktiviert) funktioniert alles ganz gut, alle (meine) Apps usw., Bluetooth meistens auch. ;) Die Akkulaufzeit ist super, je nachdem 1 - 3 Tage.🔋
# Falls euch die Kamera interessiert: Leider kein sonderlich hohes Niveau, mit der App "Open Camera" kann man aber noch ein bisschen was raus holen.
# Auf jeden Fall finde ich dieses Projekt sehr unterstützenswert, das ist ein wichtiger Schritt in die richtige Richtung! 👍👍👍 ~ Annöh
#
# #ökophone #smartphone #smartphonealternative #biophone #shiftphone #fairphone #fairsmartphone #fairtrade #fairerhandel #elektronik #fairelektronik #ressourcenschonen #rohstoffe #fair #madeingermany #madeinchina #alternative #nachhaltigkeit #nachhaltig #öko #bio #regional #ecofluencer #nachhaltigleben #umweltbewusst #umweltbewusstsein #ökologischleben #achtsamkeit #sustainability #greenblogger
# 018
# Januari #inmnhand
# 193
# Be the first to go fair.
#
# The new Fairphone, the phone that cares
# for people and planet, is now available in store exclusively to Vodafone.
# Fairphone improves the conditions of the people who make it and uses materials that are better for the planet. Because how it’s made matters.
#
# The future is exciting. Ready?
#
# #fairphone #redlovesgreen #future
# 09
# Zu viel Elektromüll - Warum nicht ein Ladegerät für alle Handys? zurl.co/rDfz Ein Standard und nicht bei jedem Produkt ein Kabel beilegen! Vorbild #fairphone
# Reply
# Retweet
# Like
# 22 Jan 2020
# 🦒 With the Giraffe, the reality can be easier considered from a higher perspective. Unique handmade bags collection for your electronic companions. Visit our Shop: www.kekoyu.com or www.etsy.com/shop/kekoyu
# .
# .
# .
# .
# .
# #friends #animals #giraffe #animalfriends #bag #handbag #embroidery #unique #artwork #textiledesign #textileart #macbooksleeve #surfacepro #fairphone #iphone #ipadpro #ipad #ipadcase #hipster #animals #bag #tote #totebag #handmade #sleeve #tasche #huelle #laptopcase #laptoptasche #kekoyu #designitnowltd
# 14
# Robinier
# #Locusts
# .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 018
# Update on the phone adventures - my Fairphone still works!
# 📞
# After one year in a drawer it’s now been charged and seems to work properly. Except for the microphone then, which was already broken before, and which I would order a new one of if I was still in Europe.
# 📞
# I was reaaaaally hoping that the feature to turn off one of the sim cards would be put back in service (Fairphone has a dual simcard functionality which is great for example when sharing life between two countries, but the possibility to turning one of them off feels sort of essential then). It was such a bummer when it (unannounced) disappeared with an update a bit over a year ago...and I was hoping that this thing would have been fixed by now. But it seems like it’s not.
# 📞
# Anyways. It’s still such a special phone and again I encourage everyone (living in Europe - as @Fairphone is not really optimized to use in other places) to check it out - either in order to get one or at least to learn more about the tech industry, #conflictminerals, #childlabor and more. So uplifting to learn about people wanting to do things in a new way like that. They’ve just launched the Fairphone 3 which probably is even better than my Fp2 in the picture ✨
# 📞
# As I’m in the US now I will nevertheless need to check for another phone to use now that my old-old one is slowly falling apart 😬 and will of course look into getting a used one again. There are so many phones already out there so I think we all could just use the ones already manufactured for a very very long time and still not run out of them. ♻️
# 📞
# Which is one of the other things about Fairphone - the idea that its owner should be able to fix it when it brakes. How revolutionary is that?? Just kidding. It should be the standard, really. But since it’s not...I guess it kind of is a bit revolutionary after all.
# 📞
# #fairphone #fairphone2 #smartphone #iphone #coltan #fairtradegold #lessimpact #repair #reuse #dualsimcard #sustainability #technology #siliconvalley #usedphones
# 25
# #digitaldetox für die Umwelt?
#
# Um herauszufinden, wie viel Energie unsere Social Media Arbeit benötigt, habe ich 41 Webseiten aufgerufen [=13g CO2].
# Mein Handy habe ich heute Morgen aufgeladen [= 22g CO2]. Davon geht für #instagram ziemlich viel Akku drauf.
#
# Letzte Woche war ich für das #teamenergiewende ca. 4 h auf Instagram. Das heißt: ich habe nicht nur für‘s Handy laden CO2 erzeugt, sondern auch durch das Abrufen von Daten von den Servern. Die brauchen Energie um z.B. gekühlt zu werden. Ein aktiver Facebook-Account erzeugt so ca. 270g CO2/Jahr– für Instagram ist es vermutlich noch mehr.
#
# Überschlagen sind das für diesen Post ca. 20,5g CO2 – genauso viel, wie eine 4-Watt-LED erzeugt, wenn sie 10h leuchtet. Das ist ziemlich viel für ein nachhaltiges Projekt.
#
# Wir sind 1 Account von 500 Mio. Aktiven. In der Summe verbrauchen wir alle extrem viel Energie. Die Zahlen waren erschreckend. Andererseits: Wir erreichen viele tolle Gleichgesinnte & schaffen einen Mehrwert durch unseren Kanal. Trotz dessen sollte man sich den Zahlen bewusst sein & ab und zu doch mal das Handy ausschalten. Was ist eure Meinung dazu? // Ronja
# .
# [Reclaimer: Die Zahlen sind nicht allgemeingültig! Der CO2-Ausstoß kann variieren, z.B. durch das Handymodell, Kohle- oder Ökostrombezug, etc.]
# .
# #energie #internet #socialmedia #cloud #speicher #grüneenergie #recherche #co2Emissionen #digital #analog #bildschirmzeit #digitalisierung #digitaleauszeit #carbonfootprint #co2fussabdruck #webseite #handy #smartphone #fairphone #facebook #verbrauch #konsum #projekt #blog
# 130
# Lebanon #Cedar over the RER station at Parc Montsouris
# .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 014
# 🇫🇷 On a fait une pause déj à Jalalabad et on a eu droit à la paille dans le café chaud... C'est beaucoup trop fréquent !
# .
# 🇬🇧 We had a lunch break in Jalalabad and we got straws in the hot coffee ... It is far too frequent!
# .
# #Kyrgyzstan #Kirghizistan #jalalabad #noplastic #BasLesPailles #nostraw #coffee
# .
# #voyage #travel #Terre #Earth #inspiration #environment #tourdumonde #rtw #worldtour #green
# .
# 📷 avec #fairphone @fairphone
# 017
# [#conçuPourDurer #AchatResponsable] 💚Lui & Moi💚
# C'est parti pour durer!! 😅
#
# PS: Saviez vous que cette marque ne donne pas de chargeur car part du principe qu'on en a sûrement déjà un!! En vrai j'en ai une 10aine...mais ce n'est plus des micro-usb 😱!!!
# Changement général (toutes les marques) pour des usb-c! Encore un beau gâchis!!😡😡 #téléphoneRéparable #Fairphone #jaimeMaPlanète #lautreAvait10ans..😅
# 18
# So sieht es aus, wenn ich für euch Instagram Beiträge verfasse ':-D
# #hinterdenkulissen #nuramhandydiealte #versunkenindenwolken #... #fairphone #kaffeemusssein #föj #föjpulli #nurfüreuch #nichtsandereszusagen
# 018
# Tree and french #police...
# .
# .
# .
# #Arbre #tree #trees #trees🌳 #treephotography #winter #Paris #Nature #Naturelovers #natureinthecity #cityscape #parisgram #naturephotography #naturephoto #naturepic #landscape #instagood #love #Photooftheday #beautiful #treesforinstagram #ilovetrees #vegetation #landscapephotography #woods #park #green #fairphone #Happy
# 224

# %%
from selenium.common.exceptions import NoSuchElementException

all_data = []

for elem in all_bubbles: 
        elem_dict = {}

        elem_dict['text_content'] = \
            elem.find_element_by_css_selector('div.j-message').text
        
        elem_dict['description'] = elem.find_element_by_css_selector('li.feed-item img').get_attribute('alt')
        
        elem_dict['original_link'] = \
            elem.find_element_by_css_selector('li.feed-item a').get_attribute('href') 
        
        try:
            elem_dict['picture'] = elem.find_element_by_css_selector('li.feed-item img').get_attribute('src')
        except NoSuchElementException: 
            elem_dict['picture'] = None
        all_data.append(elem_dict)

# %%
from selenium.common.exceptions import NoSuchElementException

all_data = []
all_bubbles = browser.find_elements_by_css_selector('li.feed-item') 

for elem in all_bubbles:
    elem_dict = {'text_content': None, 'description': None, 'original_link': None, 'picture': None}
    
    content = browser.find_element_by_css_selector('li.feed-item')  
    
    try:
        elem_dict['text_content'] = \
            content.find_element_by_css_selector('div.j-message').text
    except NoSuchElementException: 
        pass
    try:
        elem_dict['description'] = elem.find_element_by_css_selector('li.feed-item img').get_attribute('alt') 
    except NoSuchElementException:
        pass 
    try:
        elem_dict['original_link'] = \
            elem.find_element_by_css_selector('li.feed-item a').get_attribute('href') 
    except NoSuchElementException:
        pass 
    try:
        elem_dict['picture'] = elem.find_element_by_css_selector('li.feed-item img').get_attribute('src')
    except NoSuchElementException: 
        pass
    all_data.append(elem_dict)

# %%
from selenium.common.exceptions import NoSuchElementException, WebDriverException
from selenium import webdriver

def find_text_element(html_element, element_css): 
    try:
        return html_element.find_element_by_css_selector(element_css).text
    except NoSuchElementException: 
        pass
    return None

def find_attr_element(html_element, element_css, attr): 
    try:
        return html_element.find_element_by_css_selector(element_css).get_attribute(attr)
    except NoSuchElementException: 
        pass
    return None

def get_browser():
    browser = webdriver.Chrome() 
    return browser

def main():
    browser = get_browser() 
    browser.get('http://apps.twinesocial.com/fairphone')
    
    all_data = [] 
    browser.implicitly_wait(10) 
    
    try:
        all_bubbles = browser.find_elements_by_css_selector('div.twine-item-border') 
    except WebDriverException:
        browser.implicitly_wait(5)
        all_bubbles = browser.find_elements_by_css_selector('div.twine-item-border')  
        
    for elem in all_bubbles:
        elem_dict = {}
        content = elem.find_element_by_css_selector('div.content')
        elem_dict['full_name'] = find_text_element(
            content, 'div.fullname')
        elem_dict['short_name'] = find_attr_element(
            content, 'div.name', 'innerHTML')
        elem_dict['text_content'] = find_text_element(
            content, 'div.twine-description')
        elem_dict['timestamp'] = find_attr_element(
            elem, 'div.when a abbr.timeago', 'title')
        elem_dict['original_link'] = find_attr_element(
            elem, 'div.when a', 'data-href')
        elem_dict['picture'] = find_attr_element(
            content, 'div.picture img', 'src')
        all_data.append(elem_dict)
    browser.quit() 
    return all_data

if __name__ == '__main__': 
    all_data = main() 
    print (all_data)
# Out:
# [{'full_name': 'hyperlaxe (and far beyond)', 'short_name': None, 'text_content': None, 'timestamp': '2016-11-17T20:31:56.000Z', 'original_link': 'http://www.flickr.com/photos/88018310@N00/31064386195', 'picture': 'http://farm6.staticflickr.com/5349/31064386195_f2b40567db_z.jpg'}, {'full_name': 'Annemieke Westerman', 'short_name': '@Annemieke Westerman', 'text_content': None, 'timestamp': '2016-05-17T09:41:38.000Z', 'original_link': 'http://www.flickr.com/photos/28002699@N00/26465226213', 'picture': 'http://farm8.staticflickr.com/7393/26465226213_e826c09eb0_z.jpg'}, {'full_name': 'Annemieke Westerman', 'short_name': '@Annemieke Westerman', 'text_content': None, 'timestamp': '2016-04-21T09:00:35.000Z', 'original_link': 'http://www.flickr.com/photos/28002699@N00/26489458071', 'picture': 'http://farm2.staticflickr.com/1714/26489458071_efb12b96c7_z.jpg'}, {'full_name': 'samelisivonen', 'short_name': None, 'text_content': None, 'timestamp': '2016-01-01T18:10:40.000Z', 'original_link': 'http://www.flickr.com/photos/25781323@N07/24026097961', 'picture': 'http://farm2.staticflickr.com/1599/24026097961_3ed3d80dac_z.jpg'}, {'full_name': 'Martin Parkes', 'short_name': '@mrdvent', 'text_content': None, 'timestamp': '2015-07-10T06:24:36.000Z', 'original_link': 'http://www.flickr.com/photos/133636392@N07/18949494933', 'picture': 'http://farm1.staticflickr.com/531/18949494933_af38e2ac22_z.jpg'}, {'full_name': 'Fairphone', 'short_name': None, 'text_content': 'All photos should be credited to Fairphone. Creative Commons license: creativecommons.org/licenses/by-nc-sa/4.0/ This license lets others remix, tweak, and build upon our work non-commercially, as long as you credit us and license our new creations under the identical terms.', 'timestamp': '2015-02-27T10:28:30.000Z', 'original_link': 'http://www.flickr.com/photos/60295192@N08/16039060834', 'picture': 'http://farm9.staticflickr.com/8610/16039060834_aac9eb544f_z.jpg'}, {'full_name': 'Annemieke Westerman', 'short_name': '@Annemieke Westerman', 'text_content': None, 'timestamp': '2015-01-15T12:49:31.000Z', 'original_link': 'http://www.flickr.com/photos/28002699@N00/16098235438', 'picture': 'http://farm8.staticflickr.com/7509/16098235438_21a97b8fd8_z.jpg'}, {'full_name': 'András Nyiri', 'short_name': '@bolondgyermek', 'text_content': None, 'timestamp': '2014-11-24T18:40:57.000Z', 'original_link': 'http://www.flickr.com/photos/92348237@N04/15844373736', 'picture': 'http://farm9.staticflickr.com/8587/15844373736_7d7568de45_z.jpg'}, {'full_name': 'Leif Hinrichsen', 'short_name': '@Leif Hinrichsen', 'text_content': None, 'timestamp': '2014-03-15T23:47:24.000Z', 'original_link': 'http://www.flickr.com/photos/70229188@N04/13178152645', 'picture': 'http://farm4.staticflickr.com/3831/13178152645_a922401e23_z.jpg'}, {'full_name': 'Paul Miller', 'short_name': '@Paul Miller', 'text_content': None, 'timestamp': '2014-01-31T16:57:33.000Z', 'original_link': 'http://www.flickr.com/photos/24928513@N00/12238613696', 'picture': 'http://farm3.staticflickr.com/2871/12238613696_6134cbd9bc_z.jpg'}, {'full_name': 'Marco Alici', 'short_name': '@MarcoAlici', 'text_content': None, 'timestamp': '2014-01-29T22:17:16.000Z', 'original_link': 'http://www.flickr.com/photos/59315049@N07/12212000383', 'picture': 'http://farm4.staticflickr.com/3803/12212000383_f2a3ef70f5_z.jpg'}, {'full_name': 'Daniel Soluk', 'short_name': '@DanTheFlickFan', 'text_content': 'Fairphone First Edition', 'timestamp': '2014-01-19T16:41:49.000Z', 'original_link': 'http://www.flickr.com/photos/114854514@N05/12033249824', 'picture': 'http://farm4.staticflickr.com/3743/12033249824_43917dd239_z.jpg'}, {'full_name': 'Daniel Soluk', 'short_name': '@DanTheFlickFan', 'text_content': 'Fairphone First Edition', 'timestamp': '2014-01-19T16:41:49.000Z', 'original_link': 'http://www.flickr.com/photos/114854514@N05/12033249824', 'picture': 'http://farm4.staticflickr.com/3743/12033249824_43917dd239_z.jpg'}, {'full_name': 'Daniel Soluk', 'short_name': '@DanTheFlickF ...

# %%
from selenium import webdriver 
from time import sleep
    
browser = webdriver.Chrome()
browser.get('http://google.com')
inputs = browser.find_elements_by_css_selector('form input') 

for i in inputs:
    if i.is_displayed(): 
        search_bar = i
        break
        
search_bar.send_keys('web scraping with python')


#search_button = browser.find_element_by_css_selector('.FPdoLc > center:nth-child(1) > input:nth-child(1)')
search_button = browser.find_element_by_css_selector('tsf > div:nth-child(2) > div.A8SBwf.emcav > div.UUbT9 > div.aajZCb > div.tfB0Bf > center > input.gNO89b')
#inspect element > right-click that line > Copy > CSS Selector
search_button.click()

browser.implicitly_wait(10)
results = browser.find_elements_by_css_selector('div.bkWMgd h2')

for r in results:
    browser.execute_script("arguments[0].scrollIntoView({behavior: 'smooth'});",r)
    action = webdriver.ActionChains(browser) 
    action.move_to_element(r) 
    action.perform()
    sleep(2)
    
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-7-37032953610e> in <module>()
#      15
#      16 #search_button = browser.find_element_by_css_selector('.FPdoLc > center:nth-child(1) > input:nth-child(1)')
# ---> 17 search_button = browser.find_element_by_css_selector('tsf > div:nth-child(2) > div.A8SBwf.emcav > div.UUbT9 > div.aajZCb > div.tfB0Bf > center > input.gNO89b')
#      18 #inspect element > right-click that line > Copy > CSS Selector
#      19 search_button.click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"tsf > div:nth-child(2) > div.A8SBwf.emcav > div.UUbT9 > div.aajZCb > div.tfB0Bf > center > input.gNO89b"}
#   (Session info: chrome=79.0.3945.130)
