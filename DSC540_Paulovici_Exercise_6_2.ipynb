# %% [markdown]
#  # Week 6: Exercise 6.2
#  File: DSC540_Paulovici_Exercise_6_2.py (.ipynb)<br>
#  Name: Kevin Paulovici<br>
#  Date: 1/19/2020<br>
#  Course: DSC 540 Data Preparation (2203-1)<br>
#  Assignment: Exercise 6.2

# %% [markdown]
#  ## Data Files
#  Data files used for this exercise can be found here: https://github.com/jackiekazil/data-wrangling

# %% [markdown]
#  ## Fixing Labels/Headers (page 155 – 156 Data Wrangling with Python)
#  Create a new dictionary for each row to create a new array <br>
#  If you don’t want to use the method outlined in the example on page 155-156 Data Wrangling with Python, you could also use Zipping Questions and Answers as a method (page 157-163 Data Wrangling with Python).

# %%
from csv import DictReader
from csv import reader
import pprint

# read in the orig csv data and the headers to be replaced
data_rdr = DictReader(open('mn.csv', encoding='ISO-8859-1'))
header_rdr = DictReader(open('mn_headers.csv', encoding='ISO-8859-1'))

# create list of rows for each data file
data_rows = [d for d in data_rdr]
header_rows = [h for h in header_rdr]

# TODO - option print out 
#pprint.pprint(data_rows[:1])
#pprint.pprint(header_rows[:1])

# create a new dictionary for each row to create a new array
new_rows = []

# this portion looks headers to be replace
# additionally, only questions are retained
for data_dict in data_rows:
    new_row = {}
    for dkey, dval in data_dict.items():
        for header_dict in header_rows:
            if dkey in header_dict.values():
                if header_dict['Question'] != '':
                    new_row[header_dict.get('Label')] = dval
    new_rows.append(new_row)

# %% [markdown]
#  ## Data Formats Readable (page 164-165 Data Wrangling with Python)
#  Using the same dataset as the above example (mn.csv and mn_headers.csv), use the format method to make output human readable.

# %%
# output of the new_rows array, limited to 1 as an example
for row in new_rows[:1]:
    print("******** ROW (person) ********")

    for dict_item in row.items():
        print("Questions: {0[0]}\n Answer: {0[1]}".format(dict_item))
# Out:
# ******** ROW (person) ********
# Questions: Month of birth of man
#  Answer: 5
# Questions: Year of birth of man
#  Answer: 1984
# Questions: Age of man
#  Answer: 29
# Questions: Ever attended school
#  Answer: Yes
# Questions: Highest level of school attended
#  Answer: Higher
# Questions: Highest grade completed at that level
#  Answer: 31
# Questions: Can read part of the sentence
#  Answer: NA
# Questions: Frequency of reading newspaper or magazine
#  Answer: Almost every day
# Questions: Frequency of listening to the radio
#  Answer: At least once a week
# Questions: Frequency of watching TV
#  Answer: Less than once a week
# Questions: Ever used a computer
#  Answer: Yes
# Questions: Computer usage in the last 12 months
#  Answer: Yes
# Questions: Frequency of computer usage in the last month
#  Answer: Almost every day
# Questions: Ever used internet
#  Answer: Yes
# Questions: Internet usage in the last 12 months
#  Answer: Yes
# Questions: Frequency of Internet usage in the past month
#  Answer: Almost every day
# Questions: Ever fathered any children with any women
#  Answer: No
# Questions: Age when first child was born
#  Answer: NA
# Questions: Any sons or daughters living with you
#  Answer: NA
# Questions: Sons living with you
#  Answer: NA
# Questions: Daughters living with you
#  Answer: NA
# Questions: Any sons or daughters not living with you
#  Answer: NA
# Questions: Sons living elsewhere
#  Answer: NA
# Questions: Daughters living elsewhere
#  Answer: NA
# Questions: Ever had child who later died
#  Answer: No
# Questions: Boys dead
#  Answer: NA
# Questions: Girls dead
#  Answer: NA
# Questions: Same biological mother
#  Answer: NA
# Questions: Number of women respondent fathered children with
#  Answer: NA
# Questions: Month of last birth
#  Answer: NA
# Questions: Year of last birth
#  Answer: NA
# Questions: If she goes out with out telling husband: wife beating justified
#  Answer: No
# Questions: If she neglects the children: wife beating justified
#  Answer: No
# Questions: If she argues with husband: wife beating justified
#  Answer: No
# Questions: If she refuses sex with husband: wife beating justified
#  Answer: No
# Questions: If she burns the food: wife beating justified
#  Answer: No
# Questions: Currently married or living with a man
#  Answer: Yes, currently married
# Questions: Haveing other wives or liveing with other women as if you are married
#  Answer: No (Only one)
# Questions: How many other wives / partners living with you
#  Answer: NA
# Questions: Ever married or lived with a woman
#  Answer: NA
# Questions: Marital status
#  Answer: NA
# Questions: Married or lived with a woman once or more than once
#  Answer: Only once
# Questions: Month of first union
#  Answer: 9
# Questions: Year of first union
#  Answer: 2013
# Questions: Age at first union
#  Answer: NA
# Questions: Age at first sexual intercourse
#  Answer: 20
# Questions: Condom used during first sexual intercourse
#  Answer: Yes
# Questions: Time since last sexual intercourse (unit)
#  Answer: Days ago
# Questions: Time since last sexual intercourse (number)
#  Answer: 0
# Questions: Condom used at last sexual intercourse
#  Answer: No
# Questions: Relationship to last sexual partner
#  Answer: Wife
# Questions: Sex with any other person in the last 12 month
#  Answer: No
# Questions: Condom used with prior sexual partner
#  Answer: NA
# Questions: Relationship to prior sexual partner
#  Answer: NA
# Questions: Sex with any other man in the last 12 months
#  Answer: NA
# Questions: Number of sex partners in last 12 months
#  Answer: NA
# Questions: Number of sex partners in lifetime
#  Answer: 5
# Questions: Ever heard of AIDS
#  Answer: Yes
# Questions: Can avoid AIDS virus by having one uninfected partner
#  Answer: Yes
# Questions: Can get AIDS virus through supernatural means
#  Answer: No
# Questions: Can avoid AIDS virus by using a condom correctly every time
#  Answer: Yes
# Questions: Can get AIDS virus from mosquito bites
#  Answer: No
# Questions: Can get AIDS virus by sharing food with a person who has AIDS
#  Answer: No
# Questions: Healthy-looking person may have AIDS virus
#  Answer: Yes
# Questions: AIDS virus from mother to child during pregnancy
#  Answer: DK
# Questions: AIDS virus from mother to child during delivery
#  Answer: Yes
# Questions: AIDS virus from mother to child through breastfeeding
#  Answer: DK
# Questions: Should female teacher with AIDS virus be allowed to teach in school
#  Answer: Yes
# Questions: Would buy fresh vegetables from shopkeeper with AIDS virus
#  Answer: Yes
# Questions: If HH member became infected with AIDS virus, would want it to remain a secret
#  Answer: No
# Questions: Willing to care for person with AIDS in household
#  Answer: Yes
# Questions: Ever been tested for AIDS virus
#  Answer: Yes
# Questions: Most recent time of testing for AIDS virus
#  Answer: Less than 12 months ago
# Questions: Received results of AIDS virus test
#  Answer: Yes
# Questions: Know a place to get AIDS virus test
#  Answer: NA
# Questions: Ever tried cigarette smoking
#  Answer: No
# Questions: Age when cigarette was smoked for the first time
#  Answer: NA
# Questions: Currently smoking cigarettes
#  Answer: NA
# Questions: Number of cigarettes smoked in the last 24 hours
#  Answer: NA
# Questions: Number of days when cigarettes were smoked in past month
#  Answer: NA
# Questions: Ever tried any smoked tobacco products other than cigarettes
#  Answer: No
# Questions: Used any smoked tobacco products during the last month
#  Answer: NA
# Questions: Type of smoked tobacco product: Cigars
#  Answer: NA
# Questions: Type of smoked tobacco product: Water pipe
#  Answer: NA
# Questions: Type of smoked tobacco product: Cigarillos
#  Answer: NA
# Questions: Type of smoked tobacco product: Pipe
#  Answer: NA
# Questions: Type of smoked tobacco product: Other
#  Answer: NA
# Questions: Number of days when tobacco products where smoked in past month
#  Answer: NA
# Questions: Ever tried any form of smokeless tobacco products
#  Answer: No
# Questions: Used any smokeless tobacco products during the last month
#  Answer: NA
# Questions: Type of smokeless tobacco product used: Chewing tobacco
#  Answer: NA
# Questions: Type of smokeless tobacco product used: Snuff
#  Answer: NA
# Questions: Type of smokeless tobacco product used: Dip
#  Answer: NA
# Questions: Type of smokeless tobacco product used: Other
#  Answer: NA
# Questions: Number of days when smokeless tobacco products where used in past month
#  Answer: NA
# Questions: Ever drunk alcohol
#  Answer: Yes
# Questions: Age when alcohol was used for the first time
#  Answer: 16
# Questions: Number of days when at least one drink of alcohol was used in past month
#  Answer: 0
# Questions: Number of drinks usually consumed
#  Answer: NA
# Questions: Months ago net obtained
#  Answer: NA
# Questions: Net treated with an insecticide when obtained
#  Answer: NA
# Questions: Net soaked or dipped since obtained
#  Answer: NA
# Questions: Months ago net soaked or dipped
#  Answer: NA
# Questions: Persons slept under mosquito net last night
#  Answer: NA
# Questions: Person 1 who slept under net
#  Answer: NA
# Questions: Person 2 who slept under net
#  Answer: NA
# Questions: Person 3 who slept under net
#  Answer: NA
# Questions: Person 4 who slept under net
#  Answer: NA

# %% [markdown]
#  ## Data Formatting (page 167-169 Data Wrangling with Python)
#  Format the dates to determine when the interview started and ended.

# %%
count = 0

# loop over data_rows to find the times
for data_dict in data_rows:

    # create array for start/end dates
    start_date = []
    end_date = []

    # only use completed interviews
    if data_dict["MWM7"] == "Completed":
        for dkey, dval in data_dict.items():

            # day, month, year format
            if dkey == "MWM6D" or dkey == "MWM6M" or dkey == "MWM6Y":
                start_date.append(dval)
                end_date.append(dval) # interviews completed same day

            # find the time of start / end, hr:min
            if dkey == "MWM10H" or dkey == "MWM10M":
                start_date.append(dval)
            if dkey == "MWM11H" or dkey == "MWM11M":
                end_date.append(dval)

        # build the date string to print
        start = '{0[0]}/{0[1]}/{0[2]} {0[3]}:{0[4]}'.format(start_date)
        end = '{0[0]}/{0[1]}/{0[2]} {0[3]}:{0[4]}'.format(end_date)

        # only print out a few as an example
        if count < 5:
            # print out the dates
            print("****** Interview ******")
            print("Interview start time:", start)
            print("Interview end time:", end)
            print("***********************")

            count += 1
# Out:
# ****** Interview ******
# Interview start time: 7/4/2014 17:59
# Interview end time: 7/4/2014 18:7
# ***********************
# ****** Interview ******
# Interview start time: 7/4/2014 17:32
# Interview end time: 7/4/2014 17:42
# ***********************
# ****** Interview ******
# Interview start time: 8/4/2014 10:37
# Interview end time: 8/4/2014 10:52
# ***********************
# ****** Interview ******
# Interview start time: 8/4/2014 10:53
# Interview end time: 8/4/2014 11:10
# ***********************
# ****** Interview ******
# Interview start time: 12/4/2014 15:42
# Interview end time: 12/4/2014 16:0
# ***********************

# %% [markdown]
#  ## Documentation (page 208-212 Data Wrangling with Python)
#  Practice adding documentation to your code following best practices and guidance from your book. You can use previous code from the above examples, or another code example from class

# %% [markdown]
#  Documentation of comments and clearly labeled variables is used throughout code. I strive to make simple logical comments without over commentting on trivial code (which I expect a code reviewer to understand). Loops and logic are kept to a minimum without too much complexity to ease the reader on the function.
